# %% [markdown]
# The goal of this project is to identify the hottest upscale resturant neighborhood in Toronoto or NY so I can open my own upscale resturant

# %% [markdown]
# I will need to first identify all neighborhoods in Toronto and New York and then pull relevant info through API calls from Foursquare

# %% [markdown]
# Since I was provided the data for NY in a previous Lab, I will not waste any additional efforts and just use that data

# %% [markdown]
# Now that we have NY data, I will scrap Toronto data from Wikipedia

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
import json # library to handle JSON files

# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)
newyork_data
# Out:
# {'type': 'FeatureCollection',
#  'totalFeatures': 306,
#  'features': [{'type': 'Feature',
#    'id': 'nyu_2451_34572.1',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.84720052054902, 40.89470517661]},
#    'geometry_name': 'geom',
#    'properties': {'name': 'Wakefield',
#     'stacked': 1,
#     'annoline1': 'Wakefield',
#     'annoline2': None,
#     'annoline3': None,
#     'annoangle': 0.0,
#     'borough': 'Bronx',
#     'bbox': [-73.84720052054902,
#      40.89470517661,
#      -73.84720052054902,
#      40.89470517661]}},
#   {'type': 'Feature',
#    'id': 'nyu_2451_34572.2',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.82993910812398, 40.87429419303012]},
#    'geometry_name': 'geom',
#    'properties': {'name': 'Co-op City',
#     'stacked': 2,
#     'annoline1': 'Co-op',
#     'annoline2': 'City',
#     'annoline3': None,
#     'annoangle': 0.0,
#     'borough': 'Bronx',
#     'bbox': [-73.82993910812398,
#      40.87429419303012,
# ...

# %% [markdown]
# Now that we have the Json file, we can extract out the relevant data and store it in a pandas dataframe

# %%
neighborhoods_data = newyork_data['features']

# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
NY_neighborhoods = pd.DataFrame(columns=column_names)

for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    NY_neighborhoods = NY_neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    
NY_neighborhoods
# Out:
#            Borough         Neighborhood   Latitude  Longitude
# 0            Bronx            Wakefield  40.894705 -73.847201
# 1            Bronx           Co-op City  40.874294 -73.829939
# 2            Bronx          Eastchester  40.887556 -73.827806
# 3            Bronx            Fieldston  40.895437 -73.905643
# 4            Bronx            Riverdale  40.890834 -73.912585
# 5            Bronx          Kingsbridge  40.881687 -73.902818
# 6        Manhattan          Marble Hill  40.876551 -73.910660
# 7            Bronx             Woodlawn  40.898273 -73.867315
# 8            Bronx              Norwood  40.877224 -73.879391
# 9            Bronx       Williamsbridge  40.881039 -73.857446
# 10           Bronx           Baychester  40.866858 -73.835798
# 11           Bronx       Pelham Parkway  40.857413 -73.854756
# 12           Bronx          City Island  40.847247 -73.786488
# 13           Bronx         Bedford Park  40.870185 -73.885512
# ...

# %% [markdown]
# Now that we have NY data we can start scrapping the Toronto data from Wikipedia

# %%
import urllib.request
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
page = urllib.request.urlopen(url)
soup = BeautifulSoup(page, "lxml")

Postal_Code=[]
Borough=[]
Neighborhood=[]
right_table=soup.find('table', class_='wikitable sortable')


for row in right_table.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==3:
        Postal_Code.append(cells[0].find(text=True))
        Borough.append(cells[1].find(text=True))
        Neighborhood.append(cells[2].find(text=True))

df=pd.DataFrame(Postal_Code,columns=['Postal_Code'])
df['Borough']=Borough
df['Neighborhood']=Neighborhood
df.drop(df.loc[df['Borough']=='Not assigned\n'].index, inplace=True)
df
# Out:
#     Postal_Code            Borough  \
# 2          M3A
#         North York
#
# 3          M4A
#         North York
#
# 4          M5A
#   Downtown Toronto
#
# 5          M6A
#         North York
#
# 6          M7A
#   Downtown Toronto
#
# 8          M9A
#          Etobicoke
#
# 9          M1B
#        Scarborough
#
# 11         M3B
#         North York
#
# 12         M4B
#          East York
#
# 13         M5B
#   Downtown Toronto
#
# 14         M6B
#         North York
#
# 17         M9B
#          Etobicoke
#
# 18         M1C
#        Scarborough
#
# 20         M3C
#         North York
#
# 21         M4C
#          East York
#
# 22         M5C
#   Downtown Toronto
#
# 23         M6C
#               York
#
# 26         M9C
#          Etobicoke
#
# 27         M1E
#        Scarborough
#
# 30         M4E
#       East Toronto
#
# 31         M5E
#   Downtown Toronto
#
# 32         M6E
#               York
#
# 36         M1G
#        Scarborough
#
# 39         M4G
#          East York
#
# ...

# %% [markdown]
# Now that we have the neighborhoods we still need their lat long location. Once again using data from a preivous lab we can match our toronto data by postal code

# %%
df2 = pd.read_csv("http://cocl.us/Geospatial_data")
df2.rename(columns={"Postal Code": "Postal_Code"}, inplace=True)

df = df.replace('\n','', regex=True)
df3=pd.merge(df,df2)
df3=df3.drop(columns=['Postal_Code'])
df3
# Out:
#               Borough                                       Neighborhood  \
# 0          North York                                          Parkwoods
# 1          North York                                   Victoria Village
# 2    Downtown Toronto                          Regent Park, Harbourfront
# 3          North York                   Lawrence Manor, Lawrence Heights
# 4    Downtown Toronto        Queen's Park, Ontario Provincial Government
# 5           Etobicoke            Islington Avenue, Humber Valley Village
# 6         Scarborough                                     Malvern, Rouge
# 7          North York                                          Don Mills
# 8           East York                    Parkview Hill, Woodbine Gardens
# 9    Downtown Toronto                           Garden District, Ryerson
# 10         North York                                          Glencairn
# 11          Etobicoke  West Deane Park, Princess Gardens, Martin Grov...
# ...

# %% [markdown]
# Now that we all the location data for NY and Toronto we can start pulling in interesting data from Foursquare. Let's look at the ratings/# tips make up of different resturants in each neighborhood

# %%
df_all=df3.append(NY_neighborhoods)
df_all.head(305)
# Out:
#               Borough                                       Neighborhood  \
# 0          North York                                          Parkwoods
# 1          North York                                   Victoria Village
# 2    Downtown Toronto                          Regent Park, Harbourfront
# 3          North York                   Lawrence Manor, Lawrence Heights
# 4    Downtown Toronto        Queen's Park, Ontario Provincial Government
# 5           Etobicoke            Islington Avenue, Humber Valley Village
# 6         Scarborough                                     Malvern, Rouge
# 7          North York                                          Don Mills
# 8           East York                    Parkview Hill, Woodbine Gardens
# 9    Downtown Toronto                           Garden District, Ryerson
# 10         North York                                          Glencairn
# 11          Etobicoke  West Deane Park, Princess Gardens, Martin Grov...
# ...

# %% [markdown]
# Ok so we first need to generate a list of venues in these neighborhoods. Then for each of this venue, we need to do another API call in order to get its ratings and tips.

# %%
import requests

CLIENT_ID = '2LQDC5ROCOKSMQJKUBXONV2OTGHYBC5M2Q5AXQBEBUIVSAPP' # your Foursquare ID
CLIENT_SECRET = '3UFUTBH2OP54IA2TVVXP250YA2EDJO3A3DPLER5HUG31ZQYN' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

limit = 100
radius = 500
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            limit)
            
        # make the GET request
        results = requests.get(url).json()['response']['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
all_venues = getNearbyVenues(names=df3['Neighborhood'],
                                   latitudes=df3['Latitude'],
                                   longitudes=df3['Longitude']
                                  )
# Out:
# Parkwoods
# Victoria Village
# Regent Park, Harbourfront
# Lawrence Manor, Lawrence Heights
# Queen's Park, Ontario Provincial Government
# Islington Avenue, Humber Valley Village
# Malvern, Rouge
# Don Mills
# Parkview Hill, Woodbine Gardens
# Garden District, Ryerson
# Glencairn
# West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Rouge Hill, Port Union, Highland Creek
# Don Mills
# Woodbine Heights
# St. James Town
# Humewood-Cedarvale
# Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Guildwood, Morningside, West Hill
# The Beaches
# Berczy Park
# Caledonia-Fairbanks
# Woburn
# Leaside
# Central Bay Street
# Christie
# Cedarbrae
# Hillcrest Village
# Bathurst Manor, Wilson Heights, Downsview North
# Thorncliffe Park
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Scarborough Village
# Fairview, Henry Farm, Oriole
# Northwood Park, York University
# East Toronto, Broadview North (Old East York)
# ...

# %%
all_venues
# Out:
#                                            Neighborhood  \
# 0                                             Parkwoods
# 1                                             Parkwoods
# 2                                             Parkwoods
# 3                                      Victoria Village
# 4                                      Victoria Village
# 5                                      Victoria Village
# 6                                      Victoria Village
# 7                                      Victoria Village
# 8                             Regent Park, Harbourfront
# 9                             Regent Park, Harbourfront
# 10                            Regent Park, Harbourfront
# 11                            Regent Park, Harbourfront
# 12                            Regent Park, Harbourfront
# 13                            Regent Park, Harbourfront
# 14                            Regent Park, Harbourfront
# 15                            Regent Park, Harbourfront
# ...

# %%
NY_venues = getNearbyVenues(names=NY_neighborhoods['Neighborhood'],
                                   latitudes=NY_neighborhoods['Latitude'],
                                   longitudes=NY_neighborhoods['Longitude']
                                  )
# Out:
# Wakefield
# Co-op City
# Eastchester
# Fieldston
# Riverdale
# Kingsbridge
# Marble Hill
# Woodlawn
# Norwood
# Williamsbridge
# Baychester
# Pelham Parkway
# City Island
# Bedford Park
# University Heights
# Morris Heights
# Fordham
# East Tremont
# West Farms
# High  Bridge
# Melrose
# Mott Haven
# Port Morris
# Longwood
# Hunts Point
# Morrisania
# Soundview
# Clason Point
# Throgs Neck
# Country Club
# Parkchester
# Westchester Square
# Van Nest
# Morris Park
# Belmont
# Spuyten Duyvil
# North Riverdale
# Pelham Bay
# Schuylerville
# Edgewater Park
# Castle Hill
# Olinville
# Pelham Gardens
# Concourse
# Unionport
# Edenwald
# Bay Ridge
# Bensonhurst
# Sunset Park
# Greenpoint
# Gravesend
# Brighton Beach
# Sheepshead Bay
# Manhattan Terrace
# Flatbush
# Crown Heights
# East Flatbush
# Kensington
# Windsor Terrace
# Prospect Heights
# Brownsville
# Williamsburg
# Bushwick
# Bedford Stuyvesant
# Brooklyn Heights
# Cobble Hill
# Carroll Gardens
# Red Hook
# Gowanus
# Fort Greene
# ...

# %%
NY_venues
# Out:
#       Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0        Wakefield              40.894705              -73.847201
# 1        Wakefield              40.894705              -73.847201
# 2        Wakefield              40.894705              -73.847201
# 3        Wakefield              40.894705              -73.847201
# 4        Wakefield              40.894705              -73.847201
# 5        Wakefield              40.894705              -73.847201
# 6        Wakefield              40.894705              -73.847201
# 7        Wakefield              40.894705              -73.847201
# 8        Wakefield              40.894705              -73.847201
# 9        Wakefield              40.894705              -73.847201
# 10      Co-op City              40.874294              -73.829939
# 11      Co-op City              40.874294              -73.829939
# 12      Co-op City              40.874294              -73.829939
# ...

# %%
NYTO = NY_venues.append(all_venues)
NYTO
# Out:
#                                            Neighborhood  \
# 0                                             Wakefield
# 1                                             Wakefield
# 2                                             Wakefield
# 3                                             Wakefield
# 4                                             Wakefield
# 5                                             Wakefield
# 6                                             Wakefield
# 7                                             Wakefield
# 8                                             Wakefield
# 9                                             Wakefield
# 10                                           Co-op City
# 11                                           Co-op City
# 12                                           Co-op City
# 13                                           Co-op City
# 14                                           Co-op City
# 15                                           Co-op City
# ...

# %% [markdown]
# Now that we finally have the data set to work with, we can have some fun. Let's play around just to get ourselves familiar with the data.

# %%
NYTO.describe()
# Out:
#        Neighborhood Latitude  Neighborhood Longitude  Venue Latitude  \
# count           12112.000000            12112.000000    12112.000000
# mean               41.241474              -74.905283       41.241494
# std                 1.126287                2.072664        1.126299
# min                40.505334              -79.615819       40.502850
# 25%                40.690844              -74.031979       40.690349
# 50%                40.744049              -73.977059       40.743964
# 75%                40.843826              -73.915654       40.845275
# max                43.815252              -73.708847       43.815477
#
#        Venue Longitude
# count     12112.000000
# mean        -74.905195
# std           2.072687
# min         -79.621765
# 25%         -74.031417
# 50%         -73.977190
# 75%         -73.916238
# max         -73.707512

# %% [markdown]
# That was pretty useless I don't know why I did that

# %%
NYTO['Venue Category'].value_counts()
# Out:
# Pizza Place                    492
# Coffee Shop                    488
# Italian Restaurant             350
# Deli / Bodega                  289
# Bakery                         267
# Café                           266
# Bar                            255
# Sandwich Place                 237
# Park                           233
# Chinese Restaurant             222
# Grocery Store                  214
# Pharmacy                       195
# American Restaurant            187
# Mexican Restaurant             185
# Bank                           171
# Donut Shop                     168
# Ice Cream Shop                 161
# Restaurant                     156
# Gym                            151
# Sushi Restaurant               141
# Hotel                          135
# Gym / Fitness Center           134
# Japanese Restaurant            130
# Fast Food Restaurant           120
# Supermarket                    117
# Bagel Shop                     117
# Diner                          114
# ...

# %% [markdown]
# Looks like all the restaurants have the word restaurants attached to it. Let's filter out the non-retaurants

# %%
NYTO = NYTO[NYTO['Venue Category'].str.contains('Restaurant')]

# %%
NYTO
# Out:
#                                            Neighborhood  \
# 16                                           Co-op City
# 17                                           Co-op City
# 24                                          Eastchester
# 27                                          Eastchester
# 30                                          Eastchester
# 33                                          Eastchester
# 34                                          Eastchester
# 55                                          Kingsbridge
# 59                                          Kingsbridge
# 65                                          Kingsbridge
# 66                                          Kingsbridge
# 68                                          Kingsbridge
# 72                                          Kingsbridge
# 74                                          Kingsbridge
# 90                                          Kingsbridge
# 92                                          Kingsbridge
# ...

# %% [markdown]
# Looks like we got 2955 restaurants, all according to plan. Now let's pull in their rating and tips as well and hope we haven't reached our API call limit...

# %%
        # create the API request URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            40.870411,
            -73.828606, 
            1, 
            limit)
            
        # make the GET request
results = requests.get(url).json()['response']['groups'][0]['items']
        
results
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5bc797c82d2fd9002c1b3ec6',
#    'name': "Arby's",
#    'location': {'address': '2059 Bartow Avenue',
#     'lat': 40.8704113,
#     'lng': -73.828606,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.8704113,
#       'lng': -73.828606}],
#     'distance': 0,
#     'postalCode': '10475',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['2059 Bartow Avenue',
#      'Bronx, NY 10475',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d16e941735',
#      'name': 'Fast Food Restaurant',
#      'pluralName': 'Fast Food Restaurants',
#      'shortName': 'Fast Food',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#       'suffix': '.png'},
#      'primary': True}],
# ...

# %%
results[0]['venue']['id']
# Out:
# '5bc797c82d2fd9002c1b3ec6'

# %% [markdown]
# After trying for a bit I realized that tips and ratings are premium API calls and I'm not about to give Foursquare money. It's time to pivot and just look at where resturants are clustered

# %%
NYTO['Neighborhood'].value_counts()
# Out:
# Murray Hill                                                                                       55
# Greenwich Village                                                                                 44
# Astoria                                                                                           38
# Jackson Heights                                                                                   38
# Chinatown                                                                                         37
# Noho                                                                                              36
# Clinton Hill                                                                                      35
# East Village                                                                                      35
# Upper West Side                                                                                   35
# ...

# %%
top_neigh = ['Murray Hill','Greenwich Village','Astoria','Jackson Heights','Chinatown','Noho','Clinton Hill', 'East Village','Upper West Side']
d = {'Neighborhood':[], '# of italian':[], '# of resturant':[]}
df5=pd.DataFrame(data=d)
for neigh in top_neigh:
    df5=df5.append({'Neighborhood':neigh,'# of resturant':NYTO[NYTO['Neighborhood']==neigh].count()['Neighborhood'],'# of italian':NYTO[(NYTO['Neighborhood']==neigh) & (NYTO['Venue Category']=='Italian Restaurant')].count()['Venue Category']},ignore_index=True)
#for neigh in top_neigh:
 #   NYTO['Neighborhood']==neigh

# %% [markdown]
# Okay so turns out I actually want to open an italian resturant. I'd hear we look at the top foodie neighborhoods and see where there's the least penetration of italian resturants

# %%
for neigh in top_neigh:
    print(neigh)
    print(NYTO[NYTO['Neighborhood']==neigh]['Venue Category'].value_counts())
# Out:
# Murray Hill
# Korean Restaurant                22
# Japanese Restaurant               5
# American Restaurant               3
# Chinese Restaurant                2
# Jewish Restaurant                 2
# Cuban Restaurant                  2
# Mediterranean Restaurant          2
# Vietnamese Restaurant             1
# Seafood Restaurant                1
# Greek Restaurant                  1
# Italian Restaurant                1
# Thai Restaurant                   1
# Indian Restaurant                 1
# Restaurant                        1
# Shanghai Restaurant               1
# Vegetarian / Vegan Restaurant     1
# Peruvian Restaurant               1
# Sushi Restaurant                  1
# Ramen Restaurant                  1
# Fast Food Restaurant              1
# Hawaiian Restaurant               1
# Asian Restaurant                  1
# Turkish Restaurant                1
# Mexican Restaurant                1
# Name: Venue Category, dtype: int64
# Greenwich Village
# ...

# %%
df5['penetration']=df5['# of italian']/df5['# of resturant']
df5
# Out:
#         Neighborhood  # of italian  # of resturant  penetration
# 0        Murray Hill           1.0            55.0     0.018182
# 1  Greenwich Village          10.0            44.0     0.227273
# 2            Astoria           2.0            38.0     0.052632
# 3    Jackson Heights           1.0            38.0     0.026316
# 4          Chinatown           0.0            37.0     0.000000
# 5               Noho           6.0            36.0     0.166667
# 6       Clinton Hill           5.0            35.0     0.142857
# 7       East Village           2.0            35.0     0.057143
# 8    Upper West Side           5.0            35.0     0.142857

# %%
df5=df5.sort_values(by='penetration', ascending=True)
df5
# Out:
#         Neighborhood  # of italian  # of resturant  penetration
# 4          Chinatown           0.0            37.0     0.000000
# 0        Murray Hill           1.0            55.0     0.018182
# 3    Jackson Heights           1.0            38.0     0.026316
# 2            Astoria           2.0            38.0     0.052632
# 7       East Village           2.0            35.0     0.057143
# 6       Clinton Hill           5.0            35.0     0.142857
# 8    Upper West Side           5.0            35.0     0.142857
# 5               Noho           6.0            36.0     0.166667
# 1  Greenwich Village          10.0            44.0     0.227273

# %% [markdown]
# We can see that Chinatown actually have 0 Italian resturants. Some people might think it's stupid to open an Italian resturant in China Town but I disagree.
# I think people who live near chinatown will appreciate some pasta and pizzas in their lives so I'm going to choose Chinatown to open my resturant.
